# %% [markdown]
# ## 문제 37. 플로이드

# %%
# import sys
# input = sys.stdin.readline #jupyter에서는 readline이 적용이안됨
INF = int(1e9)

n = int(input())
m = int(input())

graph = [[INF] * (n+1) for _ in range(n+1)]

for i in range(1, n+1):
    for j in range(1, n+1):
        if i == j:
            graph[i][j] = 0

for _ in range(m):
    a, b, c = map(int, input().split())
    if c < graph[a][b]:
        graph[a][b] = c    

for k in range(1, n+1):
    for a in range(1, n+1):
        for b in range(1, n+1):
            graph[a][b] = min(graph[a][b], graph[a][k] + graph[k][b])
            
    
for i in range(1, n+1):
    for j in range(1, n+1):
        if graph[i][j] == INF:
            print(0, end=" ")
        else:
            print(graph[i][j], end=" ")
    print()

# %% [markdown]
# ## 문제 38. 정확한 순위 (O)

# %%
INF = int(1e9)
n, m = map(int, input().split())

graph = [[INF] * (n+1) for _ in range(n+1)]

for a in range(1, n+1):
    for b in range(1, n+1):
        if a == b:
            graph[a][b] = 0

for _ in range(m):
    a, b = map(int, input().split())
    graph[a][b] = 1
            
for k in range(1, n+1):
    for a in range(1, n+1):
        for b in range(1, n+1):
            graph[a][b] = min(graph[a][b], graph[a][k] + graph[k][b])

result = 0
print(graph)
for i in range(1, n+1):
    find_list = []
    check = n
    for j in range(1, n+1):
        if graph[i][j] == INF:
            if graph[j][i] != INF:
                check -= 1
        else:
            check -= 1
            
    if check == 0:
        result += 1
        
print(result)

# %% [markdown]
# ## 문제 39. 화성 탐사 (O)

# %%
import heapq

#상하좌우
dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]
INF = int(1e9)

def djkstra_graph(graph, n):
    a = [[] for _ in range(n*n+1)]
    
    for x in range(n):
        for y in range(n):
            for i in range(4):
                nx = x + dx[i]
                ny = y + dy[i]
                
                if nx >= 0 and nx < n and ny >= 0 and ny < n:
                    a[x*n + y + 1].append((nx*n + ny + 1, graph[nx][ny]))
    
    return a

def dijkstra(graph, distance, start):
    cost, node = start
    q = []
    heapq.heappush(q, (cost, node))
    distance[node] = cost
    
    while q:
        dist, now = heapq.heappop(q)
        
        if distance[now] < dist:
            continue
    
        for i in graph[now]:
            cost = dist + i[1]
            
            if cost < distance[i[0]]:
                distance[i[0]] = cost
                heapq.heappush(q, (cost, i[0]))
     
    return distance[-1]
    
case = int(input())
for _ in range(case):
    n = int(input())
    data = []
    distance = [INF] * (n*n + 1)
    for _ in range(n):
        data.append(list(map(int, input().split())))
    
    start = data[0][0], 1
    graph = djkstra_graph(data, n)
    
    result = dijkstra(graph, distance, start)
    print(result)
